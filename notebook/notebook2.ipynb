# %% [markdown]
# ## Load Data

# %%
import pandas as pd
from feature_engine.wrappers import SklearnTransformerWrapper
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("../data/raw/marketing_campaign.csv", sep="\t")

# %% [markdown]
# ## Process data

# %%
# Drop na
df = df.dropna()

# %%
# Get age
df = df.assign(age=df["Year_Birth"].apply(lambda row: 2021 - row))

# %%
# Get total children
df = df.assign(total_children=df["Kidhome"] + df["Teenhome"])

# %%
# Get total purchases
purchases_columns = df.filter(like="Purchases", axis=1).columns
df = df.assign(total_purchases=df[purchases_columns].sum(axis=1))

# %%
# Get enrollment years
df["Dt_Customer"] = pd.to_datetime(df["Dt_Customer"])
df = df.assign(enrollment_years=2022 - df["Dt_Customer"].dt.year)

# %%
# Get family size
size_map = {
    "Married": 2,
    "Together": 2,
    "Absurd": 1,
    "Widow": 1,
    "YOLO": 1,
    "Divorced": 1,
    "Single": 1,
    "Alone": 1,
}

df = df.assign(family_size=df["Marital_Status"].map(size_map) + df["total_children"])

# %%
# Drop features

keep_columns = [
    "Income",
    "Recency",
    "NumWebVisitsMonth",
    "Complain",
    "age",
    "total_purchases",
    "enrollment_years",
    "family_size",
]

df = df[keep_columns]

# %%
# Drop outliers
column_threshold = {"age": 90, "Income": 600000}
for col, threshold in column_threshold.items():
    df = df[df[col] < threshold].reset_index(drop=True)

# %%
# Scale features
scaler = SklearnTransformerWrapper(transformer=StandardScaler())
df = scaler.fit_transform(df)

# %%
df
# Out:
#         Income   Recency  NumWebVisitsMonth  Complain       age  \
# 0     0.287105  0.310353           0.692181  -0.09552  1.018352
# 1    -0.260882 -0.380813          -0.132545  -0.09552  1.274785
# 2     0.913196 -0.795514          -0.544908  -0.09552  0.334530
# 3    -1.176114 -0.795514           0.279818  -0.09552 -1.289547
# 4     0.294307  1.554453          -0.132545  -0.09552 -1.033114
# ...        ...       ...                ...       ...       ...
# 2207  0.430444 -0.104347          -0.132545  -0.09552  0.163575
# 2208  0.560123  0.241237           0.692181  -0.09552  1.958607
# 2209  0.233347  1.450778           0.279818  -0.09552 -1.033114
# 2210  0.803172 -1.417564          -0.957271  -0.09552  1.103830
# 2211  0.042290 -0.311697           0.692181  -0.09552  1.274785
#
#       total_purchases  enrollment_years  family_size
# 0            1.317945          1.499086    -1.758359
# 1           -1.159273         -1.417341     0.449070
# 2            0.796425          0.040872    -0.654644
# 3           -0.898513         -1.417341     0.449070
# 4            0.535666         -1.417341     0.449070
# ...               ...               ...          ...
# 2207         0.405286          0.040872     0.449070
# 2208         0.926805         -1.417341     2.656499
# 2209         0.535666         -1.417341    -1.758359
# 2210         1.057185         -1.417341     0.449070
# 2211        -0.507373          1.499086     1.552784
#
# [2212 rows x 8 columns]

# %% [markdown]
# ## Segmentation

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import AgglomerativeClustering, KMeans
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer

# %%
# Reduce dimension
pca = PCA(n_components=3)
pca_df = pd.DataFrame(pca.fit_transform(df), columns=["col1", "col2", "col3"])

# %%
# A 3D Projection Of Data In The Reduced Dimensionality Space
projection = {"x": pca_df["col1"], "y": pca_df["col2"], "z": pca_df["col3"]}

# %%
# Create 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection="3d")
ax.scatter(
    projection["x"],
    projection["y"],
    projection["z"],
    cmap="Accent",
    marker="o",
)
ax.set_title("A 3D Projection Of Data In The Reduced Dimension")
plt.show()

# %%
# Get best k cluster
elbow = KElbowVisualizer(AgglomerativeClustering(), k=10)
elbow.fit(pca_df)

k_best = elbow.elbow_value_

# %%
print(f"Best k is {k_best}")
print(f"Best score is {elbow.elbow_score_:.2f}")
# Out:
# Best k is 5
# Best score is 4322.47

# %%
# Get clusters
model = AgglomerativeClustering(n_clusters=k_best)
preds = model.fit_predict(pca_df)

# %%
# Insert clusters to df
df = df.assign(clusters=preds)

# %%
# Plot clusters
pca_df["clusters"] = preds

plt.figure(figsize=(10, 8))
ax = plt.subplot(111, projection="3d")
ax.scatter(
    projection["x"],
    projection["y"],
    projection["z"],
    s=40,
    c=pca_df["clusters"],
    marker="o",
    cmap="Accent",
)
ax.set_title("The Plot Of The Clusters")
plt.show()
